# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankitasahoo09/Ball-Game/blob/main/pandas_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request

urllib.request.urlretrieve(
    'https://gist.githubusercontent.com/aakashns/f6a004fa20c84fec53262f9a8bfee775/raw/f309558b1cf5103424cef58e2ecb8704dcd4d74c/italy-covid-daywise.csv',
    'italyreport.csv')
# Out:
# ('italyreport.csv', <http.client.HTTPMessage at 0x7e52b6626440>)

# %%
# !pip install pandas --upgrade-- quiet
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: --upgrade--

# %%
import pandas as pd

# %%
covid_df=pd.read_csv('italyreport.csv')

# %%
covid_df.info('italyreport.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        248 non-null    object
#  1   new_cases   248 non-null    float64
#  2   new_deaths  248 non-null    float64
#  3   new_tests   135 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 7.9+ KB

# %%
covid_df.describe()
# Out:
#          new_cases  new_deaths     new_tests
# count   248.000000  248.000000    135.000000
# mean   1094.818548  143.133065  31699.674074
# std    1554.508002  227.105538  11622.209757
# min    -148.000000  -31.000000   7841.000000
# 25%     123.000000    3.000000  25259.000000
# 50%     342.000000   17.000000  29545.000000
# 75%    1371.750000  175.250000  37711.000000
# max    6557.000000  971.000000  95273.000000

# %%
covid_df.columns
# Out:
# Index(['date', 'new_cases', 'new_deaths', 'new_tests'], dtype='object')

# %%
covid_df.shape
# Out:
# (248, 4)

# %%
covid_df['date']
# Out:
# 0      2019-12-31
# 1      2020-01-01
# 2      2020-01-02
# 3      2020-01-03
# 4      2020-01-04
#           ...
# 243    2020-08-30
# 244    2020-08-31
# 245    2020-09-01
# 246    2020-09-02
# 247    2020-09-03
# Name: date, Length: 248, dtype: object

# %%
covid_df.head()
# Out:
#          date  new_cases  new_deaths  new_tests
# 0  2019-12-31        0.0         0.0        NaN
# 1  2020-01-01        0.0         0.0        NaN
# 2  2020-01-02        0.0         0.0        NaN
# 3  2020-01-03        0.0         0.0        NaN
# 4  2020-01-04        0.0         0.0        NaN

# %%
covid_df.tail()
# Out:
#            date  new_cases  new_deaths  new_tests
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN

# %%
covid_df.at[125,'new_cases']
# Out:
# 1389.0

# %%
covid_df['new_cases'][246]
# Out:
# 975.0

# %%
covid_df[['date','new_cases']]
# Out:
#            date  new_cases
# 0    2019-12-31        0.0
# 1    2020-01-01        0.0
# 2    2020-01-02        0.0
# 3    2020-01-03        0.0
# 4    2020-01-04        0.0
# ..          ...        ...
# 243  2020-08-30     1444.0
# 244  2020-08-31     1365.0
# 245  2020-09-01      996.0
# 246  2020-09-02      975.0
# 247  2020-09-03     1326.0
#
# [248 rows x 2 columns]

# %%
covid_df.copy()
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
covid_df.loc[246]
# Out:
# date          2020-09-02
# new_cases          975.0
# new_deaths           8.0
# new_tests            NaN
# Name: 246, dtype: object

# %%
covid_df.loc[108:113]
# Out:
#            date  new_cases  new_deaths  new_tests
# 108  2020-04-17     3786.0       525.0        NaN
# 109  2020-04-18     3493.0       575.0        NaN
# 110  2020-04-19     3491.0       480.0        NaN
# 111  2020-04-20     3047.0       433.0     7841.0
# 112  2020-04-21     2256.0       454.0    28095.0
# 113  2020-04-22     2729.0       534.0    44248.0

# %%
total_cases= covid_df.new_cases.sum()

# %%
total_deaths= covid_df.new_deaths.sum()

# %%
death_ratio= total_deaths/total_cases

# %%
print ('The number of reported cases is {} and the number of reported death is {}'.format (int(total_cases), int(total_deaths)))
# Out:
# The number of reported cases is 271515 and the number of reported death is 35497

# %%
print('The overall reported deaths cases is {:.2f}%'.format(death_ratio*100))
# Out:
# The overall reported deaths cases is 13.07%

# %%
initial_tests=935310

# %%
#what is overall test conducted if total of 935310 test were conducted before daily test
covid_total = total_cases +initial_tests
